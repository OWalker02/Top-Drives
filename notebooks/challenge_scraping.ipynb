# %%
from pprint import pprint

from src.scraping.challenge_scraping import get_challenge_dict

# %%
challenge_cat = "Rogue"
challenge_num = 20

# %%
challenge_dict = get_challenge_dict(challenge_cat, challenge_num)
# Out:
#     _request_challenge(payload={'date': 'rogue_agents_costly_vindication_20'})) - 0.86s
#     _create_challenge_dict(scraped_challenge={'cgid': 't', 'lastEdit': 'vel_8', 'name': 'Ro..., challenge_base={'pref': 'rogue_agents_'}, challenge_specific={'suf': 'costly_vindication_20', 'rest': {'tag...)) - 0.50s
# get_challenge_dict(challenge_cat='Rogue', challenge_num=20)) - 1.37s

# %%
pprint(challenge_dict)
# Out:
# {'1': {'RQ limit': 325,
#        'RQ range': [10, 150],
#        'Restrictions': {'prize_False': 5,
#                         'rq_range_50_150': 5,
#                         'tag_Rogue_Agents': 5},
#        'Tracks': {'1': ['mile4_a01', 13.08],
#                   '2': ['csSmall_a01', 47.36],
#                   '3': ['mile2_a01', 20.93],
#                   '4': ['csMed_a01', 93.17],
#                   '5': ['mile4_a01', 13.08]}},
#  '10': {'RQ limit': 425,
#         'RQ range': [10, 150],
#         'Restrictions': {'prize_False': 5,
#                          'rq_range_50_150': 5,
#                          'tag_Rogue_Agents': 5},
#         'Tracks': {'1': ['northloop_a00', 460.61],
#                    '2': ['tCircuit_a00', 65.73],
#                    '3': ['fast_a00', 64.23],
#                    '4': ['fast_a01', 72.93],
#                    '5': ['mile4_a00', 11.45]}},
#  '2': {'RQ limit': 330,
#        'RQ range': [10, 150],
#        'Restrictions': {'prize_False': 5,
# ...
