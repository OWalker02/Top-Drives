# %%
from selenium.webdriver import Firefox, FirefoxOptions

from src.scraping.scrapers import ChallengeScraper

# %%
options = FirefoxOptions()
options.add_argument("--headless=new")
driver = Firefox(options=options)

# %%
scraper = ChallengeScraper(driver, "Skyline", 4)

# %%
scraper.challenge_path
# Out:
# WindowsPath('C:/Users/ollie/Desktop/Top-Drives/data/challenges/Skyline_Nismo_4.json')

# %%
scraper.scrape()
# Out:
# ChallengeScraper._open_challenges(self)) - 2.19s
# ChallengeScraper._select_challenge(self)) - 0.80s
# ChallengeScraper._get_round_soups(self)) - 4.26s
# ChallengeScraper._save_challenge(self)) - 0.00s
# ChallengeScraper.scrape(self)) - 7.68s

# %%
driver.quit()
