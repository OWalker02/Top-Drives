# %%
from pprint import pprint

from src.scraping.challenge_scraping import get_challenge_dict

# %%
challenge_cat = "Avatar"
challenge_num = 4

# %%
challenge_dict = get_challenge_dict(challenge_cat, challenge_num)
# Out:
#     _request_challenge(payload={'date': 'avatar_challenge_volvo_4'})) - 0.92s
#     _create_challenge_dict(scraped_challenge={'cgid': 't', 'lastEdit': 'TiagoXavi', 'name':..., challenge_base={'pref': 'avatar_challenge_'}, challenge_specific={'sr': 6, 'suf': 'volvo_4', 'rest': {'country_...)) - 0.70s
# get_challenge_dict(challenge_cat='Avatar', challenge_num=4)) - 1.63s

# %%
pprint(challenge_dict)
# Out:
# {'1': {'RQ limit': 235,
#        'RQ range': [10, 150],
#        'Restrictions': {'country_SE': 5, 'rq_range_40_150': 5},
#        'Tracks': {'1': ['dealsGap_a00', 888.97],
#                   '2': ['mile4_a00', 14.61],
#                   '3': ['fast_a00', 74.95],
#                   '4': ['hairpin_a00', 48.49],
#                   '5': ['mile1_a00', 37.41]}},
#  '10': {'RQ limit': 445,
#         'RQ range': [10, 150],
#         'Restrictions': {'country_SE': 5, 'rq_range_40_150': 5},
#         'Tracks': {'1': ['townTour_a00', 56.31],
#                    '2': ['townSprint_a01', 42.56],
#                    '3': ['forest_a00', 51.36],
#                    '4': ['townSlalom_a01', 31.01],
#                    '5': ['kart_a00', 38.73]}},
#  '2': {'RQ limit': 245,
#        'RQ range': [10, 150],
#        'Restrictions': {'country_SE': 5, 'rq_range_40_150': 5},
#        'Tracks': {'1': ['mile2_a00', 22.46],
#                   '2': ['hairpin_a00', 47.81],
#                   '3': ['dealsGap_a00', 884.46],
#                   '4': ['laguna_a00', 123.42],
#                   '5': ['hClimb_a00', 29.25]}},
#  '3': {'RQ limit': 260,
#        'RQ range': [10, 150],
#        'Restrictions': {'country_SE': 5, 'rq_range_40_150': 5},
#        'Tracks': {'1': ['fast_a00', 73.46],
#                   '2': ['lumberTwisty_a40', 122.22],
#                   '3': ['mile4_a00', 14.11],
#                   '4': ['dealsGap_a00', 877.03],
#                   '5': ['laguna_a00', 121.86]}},
#  '4': {'RQ limit': 270,
#        'RQ range': [10, 150],
#        'Restrictions': {'country_SE': 5, 'rq_range_40_150': 5},
#        'Tracks': {'1': ['slalom_a01', 33.88],
#                   '2': ['hairpin_a01', 50.79],
#                   '3': ['csMed_a01', 87.02],
#                   '4': ['carPark_a01', 51.08],
#                   '5': ['tCircuit_a01', 80.31]}},
#  '5': {'RQ limit': 245,
#        'RQ range': [10, 150],
#        'Restrictions': {'country_SE': 5, 'rq_range_40_150': 5},
#        'Tracks': {'1': ['tRoad_a60', 0],
#                   '2': ['slalom_a60', 80.9],
#                   '3': ['slalom_a60', 80.9],
#                   '4': ['tRoad_a60', 0],
#                   '5': ['mile1_a60', 54.68]}},
#  '6': {'RQ limit': 310,
#        'RQ range': [10, 150],
#        'Restrictions': {'country_SE': 5, 'rq_range_40_150': 5},
#        'Tracks': {'1': ['carPark_a01', 50.13],
#                   '2': ['mtSlalom_a00', 32.8],
#                   '3': ['kart_a00', 40.28],
#                   '4': ['forest_a00', 53.81],
#                   '5': ['mtHairpin_a01', 54.18]}},
#  '7': {'RQ limit': 300,
#        'RQ range': [10, 150],
#        'Restrictions': {'country_SE': 5, 'rq_range_40_150': 5},
#        'Tracks': {'1': ['csMed_a01', 83.72],
#                   '2': ['csSmall_a01', 42.65],
#                   '3': ['carPark_a01', 50.06],
#                   '4': ['csMed_a01', 83.72],
#                   '5': ['tRoad_a01', 82.18]}},
#  '8': {'RQ limit': 370,
#        'RQ range': [10, 150],
#        'Restrictions': {'country_SE': 5, 'rq_range_40_150': 5},
#        'Tracks': {'1': ['tCircuit_a01', 77.4],
#                   '2': ['testBowl_a00', 151],
#                   '3': ['kart_a00', 39.81],
#                   '4': ['carPark_a00', 46.61],
#                   '5': ['mile4_a00', 13.05]}},
#  '9': {'RQ limit': 400,
#        'RQ range': [10, 150],
#        'Restrictions': {'country_SE': 5, 'rq_range_40_150': 5},
#        'Tracks': {'1': ['carPark_a01', 49.59],
#                   '2': ['mtSlalom_a00', 32.28],
#                   '3': ['kart_a00', 39.53],
#                   '4': ['forest_a00', 52.33],
#                   '5': ['mtHairpin_a01', 52.69]}}}
