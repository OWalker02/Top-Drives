# %%
from selenium.webdriver import Firefox, FirefoxOptions

from src.zzz_selenium_scraping.scrapers import ChallengeScraper

# %%
options = FirefoxOptions()
# options.add_argument("--headless=new")
driver = Firefox(options=options)

# %%
scraper = ChallengeScraper(driver, "Rogue", 6, True)

# %%
scraper.challenge_path
# Out:
# WindowsPath('C:/Users/ollie/Desktop/Top-Drives/data/challenges/challenges/Rogue_Agents-_Following.json')

# %%
scraper.scrape()
# Out:
# ChallengeScraper._open_challenges(self)) - 1.31s
# ChallengeScraper._select_challenge(self)) - 0.63s
# ChallengeScraper._get_round_soups(self)) - 3.51s
# ChallengeScraper._save_challenge(self)) - 0.00s
# ChallengeScraper.scrape(self)) - 5.80s

# %%
driver.quit()
