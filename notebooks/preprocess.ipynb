# %%
import os

from config.paths import PREPROCESSED_ENC_PATH, PREPROCESSED_PATH
from src.preprocessing.preprocessing import encode_df, preprocess

# %%
df = preprocess()
# Out:
#     _merge_times_and_info()) - 1.95s
#     _handle_missing_values(df=DataFrame(21613x375))) - 0.11s
#     _convert_col_types(df=DataFrame(21613x375))) - 0.40s
#     _convert_to_secs(df=DataFrame(21613x375))) - 9.57s
#     _add_owned_info(df=DataFrame(21613x375))) - 27.27s
#     _calc_penalties(df=DataFrame(62722x386))) - 0.48s
#     _update_rid(df=DataFrame(62722x382))) - 0.16s
# preprocess(test_mode=False)) - 40.14s

# %%
df.to_csv(PREPROCESSED_PATH, index=False)

# %%
csv_size = round(os.path.getsize(PREPROCESSED_ENC_PATH) / 1024 / 1024, 1)
print(f"Csv is {csv_size} MB.")
# Out:
# Csv is 80.7 MB.

# %%
df = encode_df(df)
# Out:
# encode_df(df=DataFrame(62722x382))) - 1.10s

# %%
df.to_csv(PREPROCESSED_ENC_PATH, index=False)

# %%
csv_size = round(os.path.getsize(PREPROCESSED_ENC_PATH) / 1024 / 1024, 1)
print(f"One-hot encoded csv is {csv_size} MB.")
# Out:
# One-hot encoded csv is 80.7 MB.
