# %%
import os

from config.paths import PREPROCESSED_ENC_PATH, PREPROCESSED_PATH
from src.preprocessing.preprocessing import encode_df, preprocess

# %%
df = preprocess()
# Out:
#     _merge_times_and_info()) - 2.00s
#     _handle_missing_values(df=DataFrame(21613x375))) - 0.11s
#     _convert_col_types(df=DataFrame(21613x375))) - 0.41s
#     _convert_to_secs(df=DataFrame(21613x375))) - 2.03s
#     _add_owned_info(df=DataFrame(21613x375))) - 0.41s
#     _calc_penalties(df=DataFrame(62723x384))) - 0.50s
# preprocess(test_mode=False)) - 5.62s

# %%
df
# Out:
#        rq        make             model                   make_model  year  \
# 1      10        Fiat        750 Zagato            Abarth 750 Zagato  1956
# 3      10  Alfa Romeo  Giulietta Spider  Alfa Romeo Giulietta Spider  1955
# 4      10  Alfa Romeo  Giulietta Spider  Alfa Romeo Giulietta Spider  1955
# 5      10  Alfa Romeo  Giulietta Spider  Alfa Romeo Giulietta Spider  1955
# 6      10  Alfa Romeo             Matta             Alfa Romeo Matta  1952
# ...    ..         ...               ...                          ...   ...
# 21608  99     Peugeot      9X8 Hypercar         Peugeot 9X8 Hypercar  2022
# 21609  99     Porsche        918 Spyder           Porsche 918 Spyder  2013
# 21610  99     Porsche        918 Spyder           Porsche 918 Spyder  2013
# 21611  99     Porsche        918 Spyder           Porsche 918 Spyder  2013
# 21612  99     Porsche        918 Spyder           Porsche 918 Spyder  2013
#
#        top_speed  zero_sixty  handling  engine_up  weight_up  ...  engine_pos  \
# 1          103.0        11.2      71.0          3          2  ...        Rear
# 3          107.0        10.4      70.0          2          3  ...       Front
# 4          110.0        10.1      70.0          3          2  ...       Front
# 5          110.0         9.8      68.0          3          3  ...       Front
# 6           70.0        32.0      50.0          2          3  ...       Front
# ...          ...         ...       ...        ...        ...  ...         ...
# 21608      224.0         2.3     108.0          3          3  ...         Mid
# 21609      221.0         2.3      97.0          1          1  ...         Mid
# 21610      225.0         2.1     104.0          2          3  ...         Mid
# 21611      226.0         2.1     104.0          3          2  ...         Mid
# 21612      227.0         2.1     101.0          3          3  ...         Mid
#
#            body  brakes  car_version  owned  owned_engine_up  owned_weight_up  \
# 1         Coupe       C            0   True                3                2
# 3      Roadster       C            0  False                0                0
# 4      Roadster       C            0  False                0                0
# 5      Roadster       C            0  False                0                0
# 6           SUV       C            0   True                1                1
# ...         ...     ...          ...    ...              ...              ...
# 21608     Coupe       A            2  False                0                0
# 21609  Roadster       A            2  False                0                0
# 21610  Roadster       A            2  False                0                0
# 21611  Roadster       A            2  False                0                0
# 21612  Roadster       A            2  False                0                0
#
#        owned_chassis_up  rarity  penalty
# 1                     3       F      0.0
# 3                     0       F    179.0
# 4                     0       F    179.0
# 5                     0       F    179.0
# 6                     1       F     29.0
# ...                 ...     ...      ...
# 21608                 0       S      inf
# 21609                 0       S      inf
# 21610                 0       S      inf
# 21611                 0       S      inf
# 21612                 0       S      inf
#
# [62723 rows x 382 columns]

# %%
df.to_csv(PREPROCESSED_PATH, index=False)

# %%
csv_size = round(os.path.getsize(PREPROCESSED_ENC_PATH) / 1024 / 1024, 1)
print(f"Csv is {csv_size} MB.")
# Out:
# Csv is 80.7 MB.

# %%
df = encode_df(df)
# Out:
# encode_df(df=DataFrame(62723x382))) - 1.21s

# %%
df.to_csv(PREPROCESSED_ENC_PATH, index=False)

# %%
csv_size = round(os.path.getsize(PREPROCESSED_ENC_PATH) / 1024 / 1024, 1)
print(f"One-hot encoded csv is {csv_size} MB.")
# Out:
# One-hot encoded csv is 80.6 MB.
