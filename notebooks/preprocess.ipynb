# %%
import os

from config.paths import PREPROCESSED_ENC_PATH
from src.preprocessing.preprocessing import prep_and_encode

# %%
prep_and_encode()
# Out:
#     _merge_times_and_info()) - 1.44s
#     _handle_missing_values(df=DataFrame(23775x467))) - 0.06s
#     _convert_col_types(df=DataFrame(23775x467))) - 0.11s
#     _add_owned_info(df=DataFrame(23775x467))) - 0.55s
#     _calc_penalties(df=DataFrame(68892x476))) - 0.56s
#     _add_uid(df=DataFrame(68892x474))) - 0.24s
# preprocess(test_mode=False)) - 3.07s
# encode_df(df=DataFrame(68892x475))) - 0.27s

# %%
csv_size = round(os.path.getsize(PREPROCESSED_ENC_PATH) / 1024 / 1024, 1)
print(f"One-hot encoded csv is {csv_size} MB.")
# Out:
# One-hot encoded csv is 111.9 MB.
