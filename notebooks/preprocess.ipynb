# %%
from config.paths import PREPROCESSED_ENC_PATH, PREPROCESSED_PATH
from src.preprocessing.preprocessing import encode_df, preprocess

# %%
df = preprocess()
df.to_csv(PREPROCESSED_PATH, index=False)
# Out:
#     _merge_times_and_info()) - 0.02s
#     _handle_missing_values(df=DataFrame(66x362))) - 0.01s
#     _convert_col_types(df=DataFrame(66x362))) - 0.01s
#     _convert_to_secs(df=DataFrame(66x362))) - 0.49s
#     _add_owned_info(df=DataFrame(66x362))) - 1.45s
#     _calc_penalties(df=DataFrame(167x373))) - 0.03s
# preprocess()) - 2.01s

# %%
df_one_hot = encode_df(df)
df_one_hot.to_csv(PREPROCESSED_ENC_PATH, index=False)
# Out:
# encode_df(df=DataFrame(167x369))) - 0.03s
